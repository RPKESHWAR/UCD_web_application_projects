# %% [markdown]
# # Data Preparation

# %%
# Import pandas, numpy, matplotlib, seaborn libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages
from tabulate import tabulate
import datetime
import keras

# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction import DictVectorizer
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
import pickle
# hide ipykernel warnings 
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ## Import data

# %% [markdown]
# ### Import bike dynamic data from csv into dataframe

# %%
# Read in data as pandas dataframe and display first 5 rows
bikeDynamic = pd.read_csv('dBikeD.csv')
bikeDynamic = bikeDynamic.drop(columns=['last_update'])
bikeDynamic.tail(5)
# Out:
#         id_Entry  number status  bike_stands  available_bike_stands  \
# 369155    370900      39   OPEN           20                      6
# 369156    370901      83   OPEN           40                     27
# 369157    370902      92   OPEN           40                     25
# 369158    370903      21   OPEN           30                     22
# 369159    370904      88   OPEN           30                      9
#
#         available_bikes data_entry_timestamp
# 369155               14  2020-03-24 11:40:02
# 369156               13  2020-03-24 11:40:02
# 369157               15  2020-03-24 11:40:02
# 369158                8  2020-03-24 11:40:02
# 369159               21  2020-03-24 11:40:02

# %% [markdown]
# #### check for shape

# %%
print('The shape of our features is:', bikeDynamic.shape,'\n', bikeDynamic.dtypes)
# Out:
# The shape of our features is: (369160, 7)
#  id_Entry                  int64
# number                    int64
# status                   object
# bike_stands               int64
# available_bike_stands     int64
# available_bikes           int64
# data_entry_timestamp     object
# dtype: object

# %% [markdown]
# #### check for Null entries

# %%
bikeDynamic.isnull().sum()
# Out:
# id_Entry                 0
# number                   0
# status                   0
# bike_stands              0
# available_bike_stands    0
# available_bikes          0
# data_entry_timestamp     0
# dtype: int64

# %% [markdown]
# ### Import weather dynamic data from csv into dataframe

# %%
# Read in data as pandas dataframe and display first 5 rows
weatherDynamic = pd.read_csv('dWeatherD.csv')
bikeDynamic.reset_index(drop=True)
weatherDynamic = weatherDynamic[['main_temp','main_feels_like', 'main_pressure', 'main_humidity', \
                 'main_temp_min', 'main_temp_max', 'wind_speed', 'wind_deg', 'data_entry_timestamp']]
weatherDynamic.tail(5)
# Out:
#       main_temp  main_feels_like  main_pressure  main_humidity  main_temp_min  \
# 3437         10                7           1018             66              8
# 3438         11                9           1017             58              9
# 3439         11                9           1017             58              9
# 3440         11                9           1017             58              9
# 3441         11                7           1017             62             10
#
#       main_temp_max  wind_speed  wind_deg data_entry_timestamp
# 3437             12         2.6     150.0      8/24/2020 10:40
# 3438             12         1.0       NaN      9/24/2020 10:50
# 3439             12         1.0       NaN      10/24/2020 0:00
# 3440             12         1.0       NaN     11/24/2020 11:10
# 3441             12         4.1     200.0     12/24/2020 11:20

# %% [markdown]
# #### check for shape

# %%
print('The shape of our features is:', weatherDynamic.shape,'\n', weatherDynamic.dtypes)
# Out:
# The shape of our features is: (3442, 9)
#  main_temp                 int64
# main_feels_like           int64
# main_pressure             int64
# main_humidity             int64
# main_temp_min             int64
# main_temp_max             int64
# wind_speed              float64
# wind_deg                float64
# data_entry_timestamp     object
# dtype: object

# %% [markdown]
# #### check for Null entries

# %%
weatherDynamic.isnull().sum()
# Out:
# main_temp                 0
# main_feels_like           0
# main_pressure             0
# main_humidity             0
# main_temp_min             0
# main_temp_max             0
# wind_speed                0
# wind_deg                112
# data_entry_timestamp      0
# dtype: int64

# %% [markdown]
# #### check for Null entries

# %%
weatherDynamic.loc[weatherDynamic['wind_deg'].isnull(),('wind_deg')] = weatherDynamic['wind_deg'].ffill()

# %%
weatherDynamic.isnull().sum()
# Out:
# main_temp               0
# main_feels_like         0
# main_pressure           0
# main_humidity           0
# main_temp_min           0
# main_temp_max           0
# wind_speed              0
# wind_deg                0
# data_entry_timestamp    0
# dtype: int64

# %% [markdown]
# ## Process and normalise dates

# %% [markdown]
# **Observation on spreadsheet state that results for date 28 February and 24 March are patial. Hence, they are to be dropped for data consistency.**

# %% [markdown]
# ### dublin bikes

# %%
#DATETIME DATA

# Select columns containing datetime data
continous_date_columns = bikeDynamic[['data_entry_timestamp']].columns

# Assign object type datetime to columns enlisted in continous_date_columns
for column in continous_date_columns:
    bikeDynamic[column] = pd.to_datetime(bikeDynamic[column])   
    
# end_date = pd.to_datetime('2020-03-24')
# start_date = pd.to_datetime('2020-02-28')

# # Ommit partial data for dates 28-2-2020 and 24-3-2020
# mask = (bikeDynamic['data_entry_timestamp'].dt.date > start_date) & (bikeDynamic['data_entry_timestamp'].dt.date < end_date)
# bikeDynamic = bikeDynamic.loc[mask]

# # resolution to minutes
bikeDynamic['data_entry_timestamp'] = bikeDynamic['data_entry_timestamp'].dt.strftime("%Y-%m-%d %H:%M:00")

for column in continous_date_columns:
    bikeDynamic[column] = pd.to_datetime(bikeDynamic[column]) 
    
bikeDynamic.tail()
# Out:
#         id_Entry  number status  bike_stands  available_bike_stands  \
# 369155    370900      39   OPEN           20                      6
# 369156    370901      83   OPEN           40                     27
# 369157    370902      92   OPEN           40                     25
# 369158    370903      21   OPEN           30                     22
# 369159    370904      88   OPEN           30                      9
#
#         available_bikes data_entry_timestamp
# 369155               14  2020-03-24 11:40:00
# 369156               13  2020-03-24 11:40:00
# 369157               15  2020-03-24 11:40:00
# 369158                8  2020-03-24 11:40:00
# 369159               21  2020-03-24 11:40:00

# %%
print('The shape of our features is:', bikeDynamic.shape,'\n', bikeDynamic.dtypes)
# Out:
# The shape of our features is: (369160, 7)
#  id_Entry                          int64
# number                            int64
# status                           object
# bike_stands                       int64
# available_bike_stands             int64
# available_bikes                   int64
# data_entry_timestamp     datetime64[ns]
# dtype: object

# %% [markdown]
# ### dublin weather

# %%
#DATETIME DATA

# Select columns containing datetime data
continous_date_columns = weatherDynamic[['data_entry_timestamp']].columns

# Assign object type datetime to columns enlisted in continous_date_columns
for column in continous_date_columns:
    weatherDynamic[column] = pd.to_datetime(weatherDynamic[column])   
    
# end_date = pd.to_datetime('2020-03-24')
# start_date = pd.to_datetime('2020-02-28')

# # Ommit partial data for dates 28-2-2020 and 24-3-2020
# mask = (weatherDynamic['data_entry_timestamp'].dt.date > start_date) & (weatherDynamic['data_entry_timestamp'].dt.date < end_date)
# weatherDynamic = weatherDynamic.loc[mask]

# for column in continous_date_columns:
#     weatherDynamic[column] = pd.to_datetime(weatherDynamic[column])   
    
weatherDynamic.tail()
# Out:
#       main_temp  main_feels_like  main_pressure  main_humidity  main_temp_min  \
# 3437         10                7           1018             66              8
# 3438         11                9           1017             58              9
# 3439         11                9           1017             58              9
# 3440         11                9           1017             58              9
# 3441         11                7           1017             62             10
#
#       main_temp_max  wind_speed  wind_deg data_entry_timestamp
# 3437             12         2.6     150.0  2020-08-24 10:40:00
# 3438             12         1.0     150.0  2020-09-24 10:50:00
# 3439             12         1.0     150.0  2020-10-24 00:00:00
# 3440             12         1.0     150.0  2020-11-24 11:10:00
# 3441             12         4.1     200.0  2020-12-24 11:20:00

# %%
print('The shape of our features is:', weatherDynamic.shape,'\n', weatherDynamic.dtypes)
# Out:
# The shape of our features is: (3442, 9)
#  main_temp                        int64
# main_feels_like                  int64
# main_pressure                    int64
# main_humidity                    int64
# main_temp_min                    int64
# main_temp_max                    int64
# wind_speed                     float64
# wind_deg                       float64
# data_entry_timestamp    datetime64[ns]
# dtype: object

# %% [markdown]
# ### Merge bike and weather dataframes

# %%
bikeDynamic.head()
# Out:
#    id_Entry  number status  bike_stands  available_bike_stands  \
# 0      1745      42   OPEN           30                     17
# 1      1746      30   OPEN           20                     16
# 2      1747      54   OPEN           33                     22
# 3      1748     108   OPEN           40                     37
# 4      1749      56   OPEN           40                     13
#
#    available_bikes data_entry_timestamp
# 0               13  2020-02-28 15:00:00
# 1                4  2020-02-28 15:00:00
# 2                9  2020-02-28 15:00:00
# 3                3  2020-02-28 15:00:00
# 4               27  2020-02-28 15:00:00

# %%
weatherDynamic.head()
# Out:
#    main_temp  main_feels_like  main_pressure  main_humidity  main_temp_min  \
# 0         12                7            987             87             11
# 1         12                7            987             87             11
# 2         11                6            987             87             11
# 3         12                5            987             71             11
# 4         12                5            987             71             11
#
#    main_temp_max  wind_speed  wind_deg data_entry_timestamp
# 0             14         7.2     250.0  2020-02-28 15:00:00
# 1             14         7.2     250.0  2020-02-28 15:10:00
# 2             12         7.2     250.0  2020-02-28 15:20:00
# 3             12         8.2     250.0  2020-02-28 15:30:00
# 4             12         8.2     250.0  2020-02-28 15:40:00

# %%
dfML = pd.merge(bikeDynamic, weatherDynamic, on='data_entry_timestamp')
print(dfML.shape)
dfML.head()
# Out:
# (369160, 15)
#    id_Entry  number status  bike_stands  available_bike_stands  \
# 0      1745      42   OPEN           30                     17
# 1      1746      30   OPEN           20                     16
# 2      1747      54   OPEN           33                     22
# 3      1748     108   OPEN           40                     37
# 4      1749      56   OPEN           40                     13
#
#    available_bikes data_entry_timestamp  main_temp  main_feels_like  \
# 0               13  2020-02-28 15:00:00         12                7
# 1                4  2020-02-28 15:00:00         12                7
# 2                9  2020-02-28 15:00:00         12                7
# 3                3  2020-02-28 15:00:00         12                7
# 4               27  2020-02-28 15:00:00         12                7
#
#    main_pressure  main_humidity  main_temp_min  main_temp_max  wind_speed  \
# 0            987             87             11             14         7.2
# 1            987             87             11             14         7.2
# 2            987             87             11             14         7.2
# 3            987             87             11             14         7.2
# 4            987             87             11             14         7.2
#
#    wind_deg
# 0     250.0
# 1     250.0
# 2     250.0
# 3     250.0
# 4     250.0

# %%
print('The shape of our features is:', dfML.shape,'\n', dfML.dtypes)
# Out:
# The shape of our features is: (369160, 15)
#  id_Entry                          int64
# number                            int64
# status                           object
# bike_stands                       int64
# available_bike_stands             int64
# available_bikes                   int64
# data_entry_timestamp     datetime64[ns]
# main_temp                         int64
# main_feels_like                   int64
# main_pressure                     int64
# main_humidity                     int64
# main_temp_min                     int64
# main_temp_max                     int64
# wind_speed                      float64
# wind_deg                        float64
# dtype: object

# %% [markdown]
# ### Resolve date into time components

# %%
#Drop 'last_update' feature
dfML['year'] = dfML.data_entry_timestamp.dt.year 
dfML['Day'] = dfML.data_entry_timestamp.dt.day
dfML['month'] = dfML.data_entry_timestamp.dt.month
dfML['hour'] = dfML.data_entry_timestamp.dt.hour
dfML['minute'] = dfML.data_entry_timestamp.dt.minute
dfML['dayOfWeek'] = dfML.data_entry_timestamp.dt.weekday

# %% [markdown]
# ### Check logical integrity of data

# %% [markdown]
# **Data integrity is checked for following cases:**
#  - is "bike_stands" $>=$ "available_bike_stands" $+$ "available_bikes"  [Any other sequence is incorrect]
#  - is "last_update" $<=$ "data_entry_timestamp" [Any other sequence is incorrect]

# %%
test_1 = dfML[["id_Entry","available_bike_stands","available_bikes","bike_stands"]][dfML["available_bike_stands"].add(dfML["available_bikes"], axis=0)  >\
                                                                         dfML["bike_stands"]]
print("Number of rows failing the test: ", test_1.shape[0])
test_1.head(5)
# Out:
# Number of rows failing the test:  18
#         id_Entry  available_bike_stands  available_bikes  bike_stands
# 63885      65630                     17                0           16
# 248795    250540                     16                1           16
# 248905    250650                     16                1           16
# 249125    250870                     16                1           16
# 249235    250980                     16                1           16

# %% [markdown]
# #### Remove errors by adding available_bikes and bike_stands

# %%
dTest_1 = test_1["id_Entry"]

for data in dTest_1: 
    dfML.loc[(dfML.id_Entry == data),'bike_stands'] = dfML.loc[(dfML.id_Entry == data),'available_bikes'] + dfML.loc[(dfML.id_Entry == data),'available_bike_stands']

# %%
test_1 = dfML[["id_Entry","available_bike_stands","available_bikes","bike_stands"]][dfML["available_bike_stands"].add(dfML["available_bikes"], axis=0)  >\
                                                                         dfML["bike_stands"]]
print("Number of rows failing the test: ", test_1.shape[0])
test_1.head(5)
# Out:
# Number of rows failing the test:  0
# Empty DataFrame
# Columns: [id_Entry, available_bike_stands, available_bikes, bike_stands]
# Index: []

# %% [markdown]
# ### Set Data types prior to encoding

# %%
dfML = dfML.drop(['id_Entry', 'data_entry_timestamp'], axis = 1)
dfML.reset_index(drop = True)
# Out:
#         number status  bike_stands  available_bike_stands  available_bikes  \
# 0           42   OPEN           30                     17               13
# 1           30   OPEN           20                     16                4
# 2           54   OPEN           33                     22                9
# 3          108   OPEN           40                     37                3
# 4           56   OPEN           40                     13               27
# ...        ...    ...          ...                    ...              ...
# 369155      39   OPEN           20                      6               14
# 369156      83   OPEN           40                     27               13
# 369157      92   OPEN           40                     25               15
# 369158      21   OPEN           30                     22                8
# 369159      88   OPEN           30                      9               21
#
#         main_temp  main_feels_like  main_pressure  main_humidity  \
# 0              12                7            987             87
# 1              12                7            987             87
# 2              12                7            987             87
# 3              12                7            987             87
# 4              12                7            987             87
# ...           ...              ...            ...            ...
# 369155         12                8           1017             62
# 369156         12                8           1017             62
# 369157         12                8           1017             62
# 369158         12                8           1017             62
# 369159         12                8           1017             62
#
#         main_temp_min  main_temp_max  wind_speed  wind_deg  year  Day  month  \
# 0                  11             14         7.2     250.0  2020   28      2
# 1                  11             14         7.2     250.0  2020   28      2
# 2                  11             14         7.2     250.0  2020   28      2
# 3                  11             14         7.2     250.0  2020   28      2
# 4                  11             14         7.2     250.0  2020   28      2
# ...               ...            ...         ...       ...   ...  ...    ...
# 369155             10             12         4.1     200.0  2020   24      3
# 369156             10             12         4.1     200.0  2020   24      3
# 369157             10             12         4.1     200.0  2020   24      3
# 369158             10             12         4.1     200.0  2020   24      3
# 369159             10             12         4.1     200.0  2020   24      3
#
#         hour  minute  dayOfWeek
# 0         15       0          4
# 1         15       0          4
# 2         15       0          4
# 3         15       0          4
# 4         15       0          4
# ...      ...     ...        ...
# 369155    11      40          1
# 369156    11      40          1
# 369157    11      40          1
# 369158    11      40          1
# 369159    11      40          1
#
# [369160 rows x 19 columns]

# %%
print('The shape of our features is:', dfML.shape,'\n', dfML.dtypes)
# Out:
# The shape of our features is: (369160, 19)
#  number                     int64
# status                    object
# bike_stands                int64
# available_bike_stands      int64
# available_bikes            int64
# main_temp                  int64
# main_feels_like            int64
# main_pressure              int64
# main_humidity              int64
# main_temp_min              int64
# main_temp_max              int64
# wind_speed               float64
# wind_deg                 float64
# year                       int64
# Day                        int64
# month                      int64
# hour                       int64
# minute                     int64
# dayOfWeek                  int64
# dtype: object

# %%
# Assign data type category to columns listed in categorical_columns
categorical_columns = dfML[['status', 'year', 'month', 'dayOfWeek']].columns
for column in categorical_columns:
    dfML[column] = dfML[column].astype('category')

# %%
print('The shape of our features is:', dfML.shape)
print(dfML.dtypes)
# Out:
# The shape of our features is: (369160, 19)
# number                      int64
# status                   category
# bike_stands                 int64
# available_bike_stands       int64
# available_bikes             int64
# main_temp                   int64
# main_feels_like             int64
# main_pressure               int64
# main_humidity               int64
# main_temp_min               int64
# main_temp_max               int64
# wind_speed                float64
# wind_deg                  float64
# year                     category
# Day                         int64
# month                    category
# hour                        int64
# minute                      int64
# dayOfWeek                category
# dtype: object

# %%
dfML.head()
# Out:
#    number status  bike_stands  available_bike_stands  available_bikes  \
# 0      42   OPEN           30                     17               13
# 1      30   OPEN           20                     16                4
# 2      54   OPEN           33                     22                9
# 3     108   OPEN           40                     37                3
# 4      56   OPEN           40                     13               27
#
#    main_temp  main_feels_like  main_pressure  main_humidity  main_temp_min  \
# 0         12                7            987             87             11
# 1         12                7            987             87             11
# 2         12                7            987             87             11
# 3         12                7            987             87             11
# 4         12                7            987             87             11
#
#    main_temp_max  wind_speed  wind_deg  year  Day month  hour  minute  \
# 0             14         7.2     250.0  2020   28     2    15       0
# 1             14         7.2     250.0  2020   28     2    15       0
# 2             14         7.2     250.0  2020   28     2    15       0
# 3             14         7.2     250.0  2020   28     2    15       0
# 4             14         7.2     250.0  2020   28     2    15       0
#
#   dayOfWeek
# 0         4
# 1         4
# 2         4
# 3         4
# 4         4

# %% [markdown]
# ## Encoding

# %% [markdown]
# #### Dictionary vectorization

# %%
dfML_enc = pd.get_dummies(dfML, prefix_sep='_')
# X head
dfML_enc.head()

dfML_enc.to_csv("FeaturesGetDummies.csv")

# %%
print('Shape of features after one-hot encoding:', dfML_enc.shape)
# Out:
# Shape of features after one-hot encoding: (369160, 27)

# %% [markdown]
# ## Features and Labels

# %%
# return dataframe without target variable for processing
def prepareDF(dfML, targetCol):
    target = np.array(dfML[targetCol])
    
    # Remove the target variable from dataframe
    dfML= dfML.drop(targetCol, axis = 1)

    # Saving feature names for later use
    feature_list = list(dfML.columns)

    # Convert to numpy array
    dfML_array = np.array(dfML)
    
    return dfML_array, target, feature_list

# %% [markdown]
# ## Training and Testing Sets

# %%
def trainTestData(features, target):
    # Split the data into training and testing sets
    train_features, test_features, train_labels, test_labels = train_test_split(features, target, test_size = 0.25,
                                                                               random_state = 42)
    return train_features, test_features, train_labels, test_labels

# %% [markdown]
# ## Establish Baseline

# %%
# def baseLine(test_features, feature_list, target):
#     # The baseline predictions are the historical averages
#     baseline_preds = test_features[:, feature_list.index(target)]

#     # Baseline errors, and display average baseline error
#     baseline_errors = abs(baseline_preds - test_labels)
#     print('Average baseline error: ', round(np.mean(baseline_errors), 2), 'degrees.')

# %% [markdown]
# ## Training the Forest

# %%
def trainRandomForest(train_features, train_labels):
    # Instantiate model 
    rf = RandomForestRegressor(n_estimators= 100, random_state=42)

    # Train the random forest model
    rf.fit(train_features, train_labels)
    
    return rf

# %% [markdown]
# Model with different hyperparameters

# %%
# rf_new = RandomForestRegressor(n_estimators = 100, criterion = 'mse', max_depth = None, 
#                                min_samples_split = 2, min_samples_leaf = 1)

# %% [markdown]
# ## Make Predictions on Test Data

# %%
def predictRandomForest(rf, test_features, test_labels):
    # Use the forest's predict method on the test data
    predictions = rf.predict(test_features) 
    
    return predictions

# %% [markdown]
# ## View Results

# %%
def result(predictions,test_labels):
    # Calculate the absolute errors
    errors = abs(predictions - test_labels)

    # Print out the mean absolute error (mae)
    print('Mean Absolute Error:', round(np.mean(errors), 2))
    
    
    print('\n==============================================================================')
    print("MAE: ", metrics.mean_absolute_error(test_labels, predictions))
    print("RMSE: ", metrics.mean_squared_error(test_labels, predictions, squared=False))    
#     print("RMSE: ", metrics.mean_squared_error(test_labels, predictions)**0.5)
    print("R2: ", metrics.r2_score(test_labels, predictions))

    
    plt.plot(test_labels[:10])
#     plt.xticks(range(len(dates)), dates)
    plt.plot(predictions[:10])
    
    plt.xlabel('Time')
    plt.ylabel('Available stands')


#     plt.xlabel('Time')
#     plt.ylabel('Available stands')

    plt.show()

# %% [markdown]
# ## Variable Importances

# %%
def show_Importance(rf,features):
    # Get numerical feature importances
    importances = list(rf.feature_importances_)

    # List of tuples with variable and importance
    feature_importances = [(features, round(importance, 2)) for features, importance in zip(feature_list, importances)]

    # Sort the feature importances by most important first
    feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

    # Print out the feature and importances 
    [print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances]

# %% [markdown]
# ## Pipeline

# %%
# Data processing pipeline 

# number                      int64
# status                   category
# bike_stands                 int64
# available_bike_stands       int64
# available_bikes             int64
# main_temp                   int64
# main_feels_like             int64
# main_pressure               int64
# main_humidity               int64
# main_temp_min               int64
# main_temp_max               int64
# wind_speed                float64
# wind_deg                  float64
# year                     category
# Day                         int64
# month                    category
# hour                        int64
# minute                      int64
# dayOfWeek                   int64

targetCols = ['available_bikes','available_bike_stands']

# dfML_inputPipe = dfML_enc.drop(targetCols, axis = 1)
# print("Input columns \n", dfML_inputPipe.dtypes)


# ***************************************************************************************************************
# dfML_PipeLine = normaliseDF(dfMLweather_enc[targetCols])

# dfML_PipeLine = dfMLweather_enc[targetCols]
# print("Output columns \n", dfML_PipeLine.dtypes)
# ***************************************************************************************************************


stations = dfML_enc['number'].unique()

for station in stations:
    dfML_station = dfML_enc.loc[dfML_enc['number'] == station] 
    dfML_enc_DA = dfML_station

    
    i = 1
    
    # Array of target variables
    target = np.array(dfML_enc_DA[targetCols[i]])
    
    dfML_pipeline = dfML_enc_DA.drop(['available_bikes','available_bike_stands','number'], axis = 1)
    print(dfML_pipeline.dtypes)

    # Saving input feature names for later use
    feature_list = list(dfML_pipeline.columns)
    # Convert to numpy array
    features = np.array(dfML_pipeline)

    train_features, test_features, train_labels, test_labels = trainTestData(features, target)

    # dates = dfML_enc_DA[:, feature_list.index('data_entry_timestamp')]

    print('Training Features Shape:', train_features.shape)
    print('Training Labels Shape:', train_labels.shape)
    print('Testing Features Shape:', test_features.shape)
    print('Testing Labels Shape:', test_labels.shape)

    # baseLine()

    rfBikeModel = trainRandomForest(train_features, train_labels)
    
    # save the model
    filename = 'stn'+str(station)+"_"+targetCols[i]+'.pkl'
    pickle.dump(rfBikeModel, open(filename, 'wb'))

    # load the model 
    rfBikeModel_loaded = pickle.load(open(filename, 'rb'))    
    
    break
# Out:
# bike_stands          int64
# main_temp            int64
# main_feels_like      int64
# main_pressure        int64
# main_humidity        int64
# main_temp_min        int64
# main_temp_max        int64
# wind_speed         float64
# wind_deg           float64
# Day                  int64
# hour                 int64
# minute               int64
# status_CLOSED        uint8
# status_OPEN          uint8
# year_2020            uint8
# month_2              uint8
# month_3              uint8
# dayOfWeek_0          uint8
# dayOfWeek_1          uint8
# dayOfWeek_2          uint8
# dayOfWeek_3          uint8
# dayOfWeek_4          uint8
# dayOfWeek_5          uint8
# dayOfWeek_6          uint8
# dtype: object
# Training Features Shape: (2517, 24)
# Training Labels Shape: (2517,)
# Testing Features Shape: (839, 24)
# Testing Labels Shape: (839,)

# %%
print(test_labels)
predictions = predictRandomForest(rfBikeModel_loaded,test_features, test_labels)
result(predictions,test_labels)
show_Importance(rfBikeModel_loaded,features)
# Out:
# [ 2  6 12  5  1 30  8  0  1 12  8  0 11 28  0  9 13 24  0  8  6 18 12  0
#  14  2 24  5  0 17 10  0  7  0  5 12  0  0  6 26  1 10 14 27 15  0 14 20
#   0  4  0  0  3  1  0 14  3  0 24 30  6  0 13 15  0  0  3 30  0  9 15  4
#   4 18  6 15 13  9  3  0  2  3 26  9  8  0 27  5  5  4  3 28  7  0  0 30
#  14  0  1  3  1  8  9 30 29  1  1 27  1  9  7 28  6 11  1  0  8  7 10  7
#  14 17 13  5  2  4 28  8 17 29  3 11  8  7 10 19 30 23  1  0  7 14  2  8
#  25  0  2 27  3  8 26 30  0  9  8  0 25 24  0  4  0 29  4 18  1 11 19  8
#  13 15  7  1  1 27  4 14  9  8 12  5  4  8  9  4  4  0  0  0  0 27 25  1
#  15  7 12 18 24  8 25 27  4  7  4 23  0  4  0  1  5 14  6 27 16  4  5 26
#  26 10  3  5 11 15 23  7 13  5 12  8 13  7 13  2 24 28  0  4 26 30  4  5
#   9  0 10  5  4  0 18  0 13  7 11 23  0  7 12 22 28 30  2 12  8  7  5  3
#   8  7  8 25 11 20 24  5 26  8 17  1 20  6  1 12  1  0 12 13  2  2  3  8
#   0 11  8 15  8 13  2  0  8  0  0 28 12 28 12 11  8  6 25 13  5  8 28  3
#  12 30  4  2  2 26  5  0  2  8  0 16 26  8  8 13  7 29 23  8  3 28  2 17
#  18 15  8  6  7 11 17  4  0  4  1 27  1 15  9  9 21 10 14  4  3  5  0 12
#  26 10  8 14  7  1 28 23 12 25 10 15  1 22  0  7  8  1 12 13  0 11 10  4
#  30  7  1 11 11  1 12  0 17  7  8 13  8  6 12 10  5 24  1 10  0 28 11  0
#  20  2 30  5 21 25 27 30 18 13  0  5  0  0  1 11 12  4 28 30 21 27  4  0
#  13 23  0  9  8 27  0 12 13 12 13 10 30 12 14  2  0 13 26  5  3  0  3  1
#  11  1 13  1 15  1 25  9 21  9 28  4  3 12  3  0 26 30 15 10  8  6 15 24
#  21  1 24 28  2  3  0  0 19  8 11  3  3 16  8 11 22  6 30  0 19 11  5  2
#   4 12  1 28 27 13 22  1  0 25  4  3  0 11 11 24 30  0 10  8  6 12  3 12
#  15  3 10 18  6 23 29  4  2 14 28 10 28  3  5  0 13  8 12 12 11  1  0 15
#   0 12 16 11  9  8  6  1  0  8 12 13  3 22  2  6 25 22  8 23  9  4  1  4
#   5  0  2  2 12 10  7 11  8 11 14  4  1  2  2  1  0  1 10  8 21 11  1 20
#   1  5  8  5 29 13  4 17 12 12  3  2 24  8  3  8 29 16 15 24 13  6  7  6
#  26  0  5  7 18 11 30  0 11  1 25  0 13  7  5 19  8  6 29 12 11 23 30 11
#   1  9 10  8  9  6  0  0 20 28 29  2 13  0  6  8 10  4  0  0 19 21 27 12
#   5 10  0 20  9 14  3 12 15 14  1  9  8 11  1 11  2  4  1 10  4  8  3  1
#   9 21  9 13 15  9  8 17 12  9  0 10  8 23  1  9  6  0  6 18  7  9  0 12
#  11 12 28 14  8  6  1 11 25  4  2  5 27  8  7  0  3 21  9  4  4  9  8  1
#  28 17  4 13 13  5  7  7  0  3  1  0  0 27  7 12 17  0  5  1  8  1  0  1
#  14 13 30  0 30 28 27 14  0  6  0 28  0 10 27 25 20 25 15 14  4  3 26 24
#   0 12 12  7 11  0  0 11  6  8  4 10 15  3  3  5  9  2  2 14  8 29  1  1
#  27  5  3 28  1 30 10  7 13  0 14  0  0  0  5  6  5 28 12  2  9  4 30]
# Mean Absolute Error: 0.87
#
# ==============================================================================
# MAE:  0.8691895113230036
# RMSE:  1.3467968001808417
# R2:  0.9773299100256065
# Variable: hour                 Importance: 0.38
# Variable: Day                  Importance: 0.21
# Variable: dayOfWeek_6          Importance: 0.15
# Variable: dayOfWeek_5          Importance: 0.09
# Variable: main_pressure        Importance: 0.03
# Variable: main_feels_like      Importance: 0.02
# Variable: wind_deg             Importance: 0.02
# Variable: dayOfWeek_2          Importance: 0.02
# Variable: main_temp            Importance: 0.01
# Variable: main_humidity        Importance: 0.01
# Variable: main_temp_min        Importance: 0.01
# Variable: main_temp_max        Importance: 0.01
# Variable: wind_speed           Importance: 0.01
# Variable: minute               Importance: 0.01
# Variable: dayOfWeek_0          Importance: 0.01
# Variable: dayOfWeek_1          Importance: 0.01
# Variable: dayOfWeek_4          Importance: 0.01
# Variable: bike_stands          Importance: 0.0
# Variable: status_CLOSED        Importance: 0.0
# Variable: status_OPEN          Importance: 0.0
# Variable: year_2020            Importance: 0.0
# Variable: month_2              Importance: 0.0
# Variable: month_3              Importance: 0.0
# Variable: dayOfWeek_3          Importance: 0.0
